# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Demean and rescale numerical columns
from sklearn.preprocessing import StandardScaler

# %%
# Package which performs all required encoding of dataset variables for data science projects
#     - Fills in missing values
#     - Encodes numeric variables (demeans and scales to unit variance, unless specified)
#     - Encodes nominal variables (one-hot encodes)
#     - Encodes timestamp variables (generates a set of cyclical features)
#     - Is robust to intended boolean features being read in as strings or ints

#     - Stores important details of train set encodings (means, variances, categories) for use in transforming
#       test set
from hermes_ml.dataset_conditioner import FullEncoder

# %% [markdown]
# ### Load in example dataset

# %%
# Load in example train set dataframe
df = pd.read_csv(filepath_or_buffer='demo-dataset/dataset.csv', index_col=0, parse_dates=True)

# %%
# Load in example test set dataframe
df_test = pd.read_csv(filepath_or_buffer='demo-dataset/dataset_test.csv', index_col=0, parse_dates=True)

# %% [markdown]
# #### Temporary - convert intended datetime columns (currently strings) to datetime
#
# `pandas.read_csv` is reading timestamp features in as strings (doesn't seem to be a problem with SQLAlchemy/Redshift)
#
# In the future, this should be rolled into the `timestamp` encoder to make it more robust.

# %%
datetime_cols = ['datetimes_1', 'datetimes_2']

for datetime_col in datetime_cols:
    df[datetime_col] = pd.to_datetime(df[datetime_col])
    df_test[datetime_col] = pd.to_datetime(df_test[datetime_col])

# %% [markdown]
# ### Inspect dataset

# %%
df.head(5)
# Out:
#                  datetimes_1         datetimes_2  numeric_1  numeric_2  \
# 0 2019-09-25 13:55:32.331191 2002-11-27 04:14:51  46.552984  13.739006
# 1 2019-07-08 17:03:04.331191 2012-12-20 03:31:36  25.588787        NaN
# 2 2019-06-18 23:49:57.331191 2008-12-10 18:12:54  25.487432   6.182592
# 3 2019-12-13 10:48:00.331191 2000-03-21 22:02:23   4.535463  15.181189
# 4 2019-10-15 07:08:39.331191 2010-12-15 22:52:15  24.660904   1.107595
#
#    numeric_3  boolean_like_1  boolean_like_2  boolean_like_3  boolean_like_4  \
# 0        NaN            True            True           False           False
# 1        NaN           False           False            True           False
# 2        NaN           False            True           False           False
# 3   9.776362           False           False           False            True
# 4        NaN            True           False           False           False
#
#    boolean nominal                   ordinal_1
# 0     True     Dog                       agree
# 1    False     Dog              strongly agree
# 2     True     Dog                    disagree
# 3    False     Dog           strongly disagree
# 4    False  Lizard  neither agree nor disagree

# %%
df_test.head(5)
# Out:
#                  datetimes_1         datetimes_2    numeric_1  numeric_2  \
# 0 2022-12-05 00:00:19.201864 2060-06-16 11:48:44  1085.363773        NaN
# 1 2019-11-07 02:32:40.201864 2014-07-25 09:19:08   924.379152  42.915310
# 2 2019-07-31 12:27:05.201864 2055-09-05 08:03:09   566.488961  34.995786
# 3 2023-07-29 14:37:43.201864 2090-02-05 15:55:21   822.036241        NaN
# 4 2020-08-09 03:36:18.201864 2087-03-25 23:16:00   679.786375        NaN
#
#    numeric_3  boolean_like_1  boolean_like_2  boolean_like_3  boolean_like_4  \
# 0        NaN           False            True           False           False
# 1        NaN           False           False            True            True
# 2        NaN            True            True           False            True
# 3  18.199072            True           False            True            True
# 4        NaN           False           False            True            True
#
#    boolean nominal                   ordinal_1
# 0    False   Mouse  neither agree nor disagree
# 1     True   Mouse           strongly disagree
# 2     True     Dog                    disagree
# 3    False     Cat              strongly agree
# 4     True  Iguana           strongly disagree

# %% [markdown]
# ### Specify input lookup table
#
# The hermes-ml `FullEncoder` takes a lookup table specifying {`feature`, `dtype`, `missing value fill method`} for each feature

# %%
useful_cols = pd.DataFrame(
    data=[
        ['datetimes_1', 'timestamp', 'skip'], 
        ['datetimes_2', 'timestamp', 'skip'], 
        ['numeric_1', 'numeric', 'mean'], 
        ['numeric_2', 'numeric', 'mean'],
        ['numeric_3', 'numeric', 'zeros'],
        ['boolean_like_1', 'bool', 'skip'], 
        ['boolean_like_2', 'bool', 'skip'], 
        ['boolean_like_3', 'bool', 'skip'], 
        ['boolean_like_4', 'bool', 'skip'],
        ['boolean', 'bool', 'skip'], 
        ['nominal', 'nominal', 'skip'], 
        ['ordinal_1', 'ordinal', 'skip'],
    ],
    columns=[
        'feature',
        'dtype',
        'fillna',
    ]
)

# %% [markdown]
# #### Visualise the resulting lookup table

# %%
useful_cols
# Out:
#            feature      dtype fillna
# 0      datetimes_1  timestamp   skip
# 1      datetimes_2  timestamp   skip
# 2        numeric_1    numeric   mean
# 3        numeric_2    numeric   mean
# 4        numeric_3    numeric  zeros
# 5   boolean_like_1       bool   skip
# 6   boolean_like_2       bool   skip
# 7   boolean_like_3       bool   skip
# 8   boolean_like_4       bool   skip
# 9          boolean       bool   skip
# 10         nominal    nominal   skip
# 11       ordinal_1    ordinal   skip

# %% [markdown]
# ## Encoder - train set

# %% [markdown]
# Run the `kangchenjunga.fit_transform` method on the train set `df` to encode features and store means, variances, categorical columns etc for future use on the test set

# %%
# Instantiate the encoder object
enc = FullEncoder()

# %%
# Fit encoder on training set and transform it
features_encoded = enc.fit_transform(df, useful_cols)
# Out:
# Filling in missing values...
# Missing values filled
# Encoding numeric features...
# Numeric features encoded
# Encoding nominal features...
# Nominal features encoded
# Encoding timestamp features...
# /Users/TomWalker/Dropbox (ClearScore)/Analytics/TW/hermes-ml/hermes_ml/dataset_conditioner.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   column.loc[idx_nans[name]] = means[name]
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/pandas/core/frame.py:3787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# Timestamp features encoded
# Encoding boolean features...
# Boolean features encoded
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# Have a look at the resulting encoded dataframe

# %%
enc.means_
# Out:
# numeric_1    25.033286
# numeric_2     9.954886
# dtype: float64

# %%
features_encoded.head(5)
# Out:
#    numeric_1  numeric_2  numeric_3  nominal_Cat  nominal_Dog  nominal_Lizard  \
# 0   1.725953   0.797663  -0.395583            0            1               0
# 1   0.044553   0.000000  -0.395583            0            1               0
# 2   0.036424  -0.795170  -0.395583            0            1               0
# 3  -1.643995   1.101664   3.141981            0            1               0
# 4  -0.029866  -1.864939  -0.395583            0            0               1
#
#    datetimes_1_sin_second_of_day  datetimes_1_cos_second_of_day  \
# 0                      -0.483028                      -0.875605
# 1                      -0.969302                      -0.245871
# 2                      -0.043837                       0.999039
# 3                       0.309017                      -0.951057
# 4                       0.955472                      -0.295083
#
#    datetimes_1_sin_day_of_week  datetimes_1_cos_day_of_week   ...     \
# 0                     0.974928                    -0.222521   ...
# 1                     0.000000                     1.000000   ...
# 2                     0.781831                     0.623490   ...
# 3                    -0.433884                    -0.900969   ...
# 4                     0.781831                     0.623490   ...
#
#    datetimes_2_sin_day_of_week  datetimes_2_cos_day_of_week  \
# 0                     0.974928                    -0.222521
# 1                     0.433884                    -0.900969
# 2                     0.974928                    -0.222521
# 3                     0.781831                     0.623490
# 4                     0.974928                    -0.222521
#
#    datetimes_2_sin_month_of_year  datetimes_2_cos_month_of_year  \
# 0                  -5.000000e-01                   8.660254e-01
# 1                  -2.449294e-16                   1.000000e+00
# 2                  -2.449294e-16                   1.000000e+00
# 3                   1.000000e+00                   6.123234e-17
# 4                  -2.449294e-16                   1.000000e+00
#
#    datetimes_2_year  boolean_like_1  boolean_like_2  boolean_like_3  \
# 0         -1.043281            True            True           False
# 1          1.564922           False           False            True
# 2          0.521641           False            True           False
# 3         -1.564922           False           False           False
# 4          1.043281            True           False           False
#
#    boolean_like_4  boolean
# 0           False     True
# 1           False    False
# 2           False     True
# 3            True    False
# 4           False    False
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Encoder - test set

# %% [markdown]
# Run the `kangchenjunga.transform` method on the test set `df_test` to encode features using the means, variances, categorical columns etc generated on the train set

# %%
# Transform test set using encoding attributes learnt on the train set (means, variances, categories)
features_encoded_test = enc.transform(df_test, useful_cols)
# Out:
# Filling in missing values...
# Missing values filled
# Encoding numeric features...
# Numeric features encoded
# Encoding nominal features...
# missing_test_cols: {'nominal_Lizard'}
# extra_test_cols: {'nominal_Mouse', 'nominal_Iguana'}
# set difference after sorting: set()
# Test set cols in same order as train set: True
# Nominal features encoded
# Encoding timestamp features...
# Timestamp features encoded
# Encoding boolean features...
# Boolean features encoded
# /Users/TomWalker/Dropbox (ClearScore)/Analytics/TW/hermes-ml/hermes_ml/dataset_conditioner.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   column.loc[idx_nans[name]] = means[name]
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/pandas/core/frame.py:3787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
features_encoded_test.head(5)
# Out:
#    numeric_1  numeric_2  numeric_3  nominal_Cat  nominal_Dog  nominal_Lizard  \
# 0  85.042120   0.000000  -0.395583            0            0               0
# 1  72.130605   6.947798  -0.395583            0            0               0
# 2  43.426591   5.278425  -0.395583            0            1               0
# 3  63.922354   0.000000   6.189728            1            0               0
# 4  52.513430   0.000000  -0.395583            0            0               0
#
#    datetimes_1_sin_second_of_day  datetimes_1_cos_second_of_day  \
# 0                       0.001382                       0.999999
# 1                       0.617951                       0.786217
# 2                      -0.117898                      -0.993026
# 3                      -0.635124                      -0.772410
# 4                       0.809786                       0.586726
#
#    datetimes_1_sin_day_of_week  datetimes_1_cos_day_of_week   ...     \
# 0                     0.000000                     1.000000   ...
# 1                     0.433884                    -0.900969   ...
# 2                     0.974928                    -0.222521   ...
# 3                    -0.974928                    -0.222521   ...
# 4                    -0.781831                     0.623490   ...
#
#    datetimes_2_sin_day_of_week  datetimes_2_cos_day_of_week  \
# 0                     0.974928                    -0.222521
# 1                    -0.433884                    -0.900969
# 2                    -0.781831                     0.623490
# 3                    -0.781831                     0.623490
# 4                     0.781831                     0.623490
#
#    datetimes_2_sin_month_of_year  datetimes_2_cos_month_of_year  \
# 0                   1.224647e-16                  -1.000000e+00
# 1                  -5.000000e-01                  -8.660254e-01
# 2                  -1.000000e+00                  -1.836970e-16
# 3                   8.660254e-01                   5.000000e-01
# 4                   1.000000e+00                   6.123234e-17
#
#    datetimes_2_year  boolean_like_1  boolean_like_2  boolean_like_3  \
# 0          0.468768           False            True           False
# 1         -1.197640           False           False            True
# 2          0.287637            True            True           False
# 3          1.555556            True           False            True
# 4          1.446877           False           False            True
#
#    boolean_like_4  boolean
# 0           False    False
# 1            True     True
# 2            True     True
# 3            True    False
# 4            True     True
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Save/load encoder to file

# %%
enc.save_encoder('demo_encoding')

# %% [markdown]
# Previous dataset encodings can be loaded from file

# %%
from hermes_ml.dataset_conditioner import load_encoder

# %%
enc_copy = load_encoder('demo_encoding')

# %%
features_encoded_test_after_reload = enc_copy.transform(df_test, useful_cols)
# Out:
# Filling in missing values...
# Missing values filled
# Encoding numeric features...
# Numeric features encoded
# Encoding nominal features...
# missing_test_cols: {'nominal_Lizard'}
# extra_test_cols: {'nominal_Mouse', 'nominal_Iguana'}
# set difference after sorting: set()
# Test set cols in same order as train set: True
# Nominal features encoded
# Encoding timestamp features...
# Timestamp features encoded
# Encoding boolean features...
# Boolean features encoded
# /Users/TomWalker/Dropbox (ClearScore)/Analytics/TW/hermes-ml/hermes_ml/dataset_conditioner.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   column.loc[idx_nans[name]] = means[name]
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/pandas/core/frame.py:3787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# /Users/TomWalker/anaconda3/envs/dsc_env/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
features_encoded_test.head(3)
# Out:
#    numeric_1  numeric_2  numeric_3  nominal_Cat  nominal_Dog  nominal_Lizard  \
# 0  85.042120   0.000000  -0.395583            0            0               0
# 1  72.130605   6.947798  -0.395583            0            0               0
# 2  43.426591   5.278425  -0.395583            0            1               0
#
#    datetimes_1_sin_second_of_day  datetimes_1_cos_second_of_day  \
# 0                       0.001382                       0.999999
# 1                       0.617951                       0.786217
# 2                      -0.117898                      -0.993026
#
#    datetimes_1_sin_day_of_week  datetimes_1_cos_day_of_week   ...     \
# 0                     0.000000                     1.000000   ...
# 1                     0.433884                    -0.900969   ...
# 2                     0.974928                    -0.222521   ...
#
#    datetimes_2_sin_day_of_week  datetimes_2_cos_day_of_week  \
# 0                     0.974928                    -0.222521
# 1                    -0.433884                    -0.900969
# 2                    -0.781831                     0.623490
#
#    datetimes_2_sin_month_of_year  datetimes_2_cos_month_of_year  \
# 0                   1.224647e-16                  -1.000000e+00
# 1                  -5.000000e-01                  -8.660254e-01
# 2                  -1.000000e+00                  -1.836970e-16
#
#    datetimes_2_year  boolean_like_1  boolean_like_2  boolean_like_3  \
# 0          0.468768           False            True           False
# 1         -1.197640           False           False            True
# 2          0.287637            True            True           False
#
#    boolean_like_4  boolean
# 0           False    False
# 1            True     True
# 2            True     True
#
# [3 rows x 25 columns]

# %%
features_encoded_test_after_reload.head(3)
# Out:
#    numeric_1  numeric_2  numeric_3  nominal_Cat  nominal_Dog  nominal_Lizard  \
# 0  85.042120   0.000000  -0.395583            0            0               0
# 1  72.130605   6.947798  -0.395583            0            0               0
# 2  43.426591   5.278425  -0.395583            0            1               0
#
#    datetimes_1_sin_second_of_day  datetimes_1_cos_second_of_day  \
# 0                       0.001382                       0.999999
# 1                       0.617951                       0.786217
# 2                      -0.117898                      -0.993026
#
#    datetimes_1_sin_day_of_week  datetimes_1_cos_day_of_week   ...     \
# 0                     0.000000                     1.000000   ...
# 1                     0.433884                    -0.900969   ...
# 2                     0.974928                    -0.222521   ...
#
#    datetimes_2_sin_day_of_week  datetimes_2_cos_day_of_week  \
# 0                     0.974928                    -0.222521
# 1                    -0.433884                    -0.900969
# 2                    -0.781831                     0.623490
#
#    datetimes_2_sin_month_of_year  datetimes_2_cos_month_of_year  \
# 0                   1.224647e-16                  -1.000000e+00
# 1                  -5.000000e-01                  -8.660254e-01
# 2                  -1.000000e+00                  -1.836970e-16
#
#    datetimes_2_year  boolean_like_1  boolean_like_2  boolean_like_3  \
# 0          0.468768           False            True           False
# 1         -1.197640           False           False            True
# 2          0.287637            True            True           False
#
#    boolean_like_4  boolean
# 0           False    False
# 1            True     True
# 2            True     True
#
# [3 rows x 25 columns]
